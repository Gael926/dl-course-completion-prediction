# %% [markdown]
# # Modèles TensorFlow - Classification et Régression
#
# Ce notebook implémente deux modèles avec TensorFlow/Keras :
# - **Classification** : Prédire si un étudiant va compléter le cours (`Completed`).
# - **Régression** : Prédire les scores et la satisfaction (`Quiz_Score_Avg`, `Project_Grade`, `Satisfaction_Rating`, `Time_Spent_Hours`).

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Input, BatchNormalization, Activation
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score
import matplotlib.pyplot as plt

# %% [markdown]
# ## 1. Chargement des données

# %%
# Chargement des fichiers exportés
X_class = pd.read_csv('../data/processed/X_classification.csv')
y_class = pd.read_csv('../data/processed/y_classification.csv')

X_reg = pd.read_csv('../data/processed/X_regression.csv')
y_reg = pd.read_csv('../data/processed/y_regression.csv')

print("Datasets chargés successfully.")
print(f"Classification : X={X_class.shape}, y={y_class.shape}")
print(f"Régression : X={X_reg.shape}, y={y_reg.shape}")
# Out:
# Datasets chargés successfully.
# Classification : X=(56172, 42), y=(56172, 1)
# Régression : X=(56172, 37), y=(56172, 4)

# %% [markdown]
# ## 2. PARTIE 1 : CLASSIFICATION
# ---
#
# Objectif : Prédire la colonne `Completed` (0 ou 1).

# %%
# Split des données
X_train_c, X_test_c, y_train_c, y_test_c = train_test_split(
    X_class.values, y_class.values.ravel(), test_size=0.15, random_state=42
)

# %%
# Création du modèle de classification (simplifié pour éviter l'overfitting)
model_class = Sequential([
    Input(shape=(X_train_c.shape[1],)),
    
    Dense(128),
    BatchNormalization(),
    Activation('relu'),
    Dropout(0.4),
    
    Dense(64),
    BatchNormalization(),
    Activation('relu'),
    Dropout(0.3),
    
    Dense(32),
    BatchNormalization(),
    Activation('relu'),
    Dropout(0.2),
    
    Dense(1, activation='sigmoid')
])

optimizer = tf.keras.optimizers.Adam(learning_rate=0.001)
model_class.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])
model_class.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 128)            │         5,504 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 128)            │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation (Activation)         │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 64)             │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_1 (Activation)       │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 32)             │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_2 (Activation)       │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 16,769 (65.50 KB)
#  Trainable params: 16,321 (63.75 KB)
#  Non-trainable params: 448 (1.75 KB)

# %%
# Callbacks pour stabiliser l'apprentissage
callbacks = [
    tf.keras.callbacks.EarlyStopping(
        monitor='val_loss',
        patience=30, # Arrêt si aucune amélioration après 30 époques
        restore_best_weights=True
    ),
    tf.keras.callbacks.ReduceLROnPlateau(
        monitor='val_loss',
        factor=0.2,   # Divise le LR par 5 si on stagne
        patience=10,  # Après 10 époques sans progrès
        min_lr=1e-6,
        verbose=1
    )
]
history_class = model_class.fit(
    X_train_c, y_train_c, 
    epochs=500, 
    batch_size=64,
    validation_split=0.2,
    callbacks=callbacks,
    verbose=1
)
# Out:
# Epoch 1/500
# 597/597 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.5586 - loss: 0.7035 - val_accuracy: 0.5950 - val_loss: 0.6672 - learning_rate: 0.0010
# Epoch 2/500
# 597/597 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.5860 - loss: 0.6721 - val_accuracy: 0.5948 - val_loss: 0.6645 - learning_rate: 0.0010
# Epoch 3/500
# 597/597 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6005 - loss: 0.6645 - val_accuracy: 0.5978 - val_loss: 0.6637 - learning_rate: 0.0010
# Epoch 4/500
# 597/597 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6050 - loss: 0.6621 - val_accuracy: 0.5955 - val_loss: 0.6639 - learning_rate: 0.0010
# Epoch 5/500
# 597/597 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6042 - loss: 0.6616 - val_accuracy: 0.5994 - val_loss: 0.6636 - learning_rate: 0.0010
# Epoch 6/500
# 597/597 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6060 - loss: 0.6607 - val_accuracy: 0.5976 - val_loss: 0.6633 - learning_rate: 0.0010
# Epoch 7/500
# 597/597 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6062 - loss: 0.6593 - val_accuracy: 0.5950 - val_loss: 0.6637 - learning_rate: 0.0010
# Epoch 8/500
# 597/597 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6085 - loss: 0.6594 - val_accuracy: 0.5969 - val_loss: 0.6634 - learning_rate: 0.0010
# Epoch 9/500
# 597/597 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6093 - loss: 0.6586 - val_accuracy: 0.5981 - val_loss: 0.6634 - learning_rate: 0.0010
# Epoch 10/500
# 597/597 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.6069 - loss: 0.6590 - val_accuracy: 0.5979 - val_loss: 0.6638 - learning_rate: 0.0010
# Epoch 11/500
# 597/597 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.6094 - loss: 0.6576 - val_accuracy: 0.5950 - val_loss: 0.6651 - learning_rate: 0.0010
# Epoch 12/500
# 597/597 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6090 - loss: 0.6578 - val_accuracy: 0.5965 - val_loss: 0.6636 - learning_rate: 0.0010
# Epoch 13/500
# 597/597 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6115 - loss: 0.6569 - val_accuracy: 0.5970 - val_loss: 0.6635 - learning_rate: 0.0010
# Epoch 14/500
# 597/597 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6124 - loss: 0.6564 - val_accuracy: 0.5976 - val_loss: 0.6651 - learning_rate: 0.0010
# Epoch 15/500
# 597/597 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.6123 - loss: 0.6566 - val_accuracy: 0.5983 - val_loss: 0.6640 - learning_rate: 0.0010
# Epoch 16/500
# 575/597 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6169 - loss: 0.6536
# Epoch 16: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 597/597 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6125 - loss: 0.6556 - val_accuracy: 0.5953 - val_loss: 0.6639 - learning_rate: 0.0010
# Epoch 17/500
# 597/597 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6157 - loss: 0.6547 - val_accuracy: 0.5960 - val_loss: 0.6640 - learning_rate: 2.0000e-04
# Epoch 18/500
# 597/597 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6177 - loss: 0.6540 - val_accuracy: 0.5961 - val_loss: 0.6640 - learning_rate: 2.0000e-04
# Epoch 19/500
# 597/597 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6112 - loss: 0.6538 - val_accuracy: 0.5964 - val_loss: 0.6640 - learning_rate: 2.0000e-04
# Epoch 20/500
# 597/597 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6156 - loss: 0.6539 - val_accuracy: 0.5968 - val_loss: 0.6642 - learning_rate: 2.0000e-04
# Epoch 21/500
# 597/597 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6159 - loss: 0.6532 - val_accuracy: 0.5979 - val_loss: 0.6641 - learning_rate: 2.0000e-04
# Epoch 22/500
# 597/597 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6170 - loss: 0.6532 - val_accuracy: 0.5971 - val_loss: 0.6648 - learning_rate: 2.0000e-04
# Epoch 23/500
# 597/597 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.6156 - loss: 0.6530 - val_accuracy: 0.5975 - val_loss: 0.6647 - learning_rate: 2.0000e-04
# Epoch 24/500
# 597/597 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.6162 - loss: 0.6529 - val_accuracy: 0.5969 - val_loss: 0.6646 - learning_rate: 2.0000e-04
# Epoch 25/500
# 597/597 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.6137 - loss: 0.6536 - val_accuracy: 0.5977 - val_loss: 0.6644 - learning_rate: 2.0000e-04
# Epoch 26/500
# 593/597 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6226 - loss: 0.6507
# Epoch 26: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# 597/597 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.6163 - loss: 0.6535 - val_accuracy: 0.5976 - val_loss: 0.6646 - learning_rate: 2.0000e-04
# Epoch 27/500
# 597/597 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.6161 - loss: 0.6524 - val_accuracy: 0.5974 - val_loss: 0.6648 - learning_rate: 4.0000e-05
# Epoch 28/500
# 597/597 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.6168 - loss: 0.6523 - val_accuracy: 0.5977 - val_loss: 0.6648 - learning_rate: 4.0000e-05
# Epoch 29/500
# 597/597 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6186 - loss: 0.6517 - val_accuracy: 0.5972 - val_loss: 0.6649 - learning_rate: 4.0000e-05
# Epoch 30/500
# 597/597 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6181 - loss: 0.6522 - val_accuracy: 0.5971 - val_loss: 0.6649 - learning_rate: 4.0000e-05
# Epoch 31/500
# 597/597 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.6176 - loss: 0.6524 - val_accuracy: 0.5968 - val_loss: 0.6650 - learning_rate: 4.0000e-05
# Epoch 32/500
# 597/597 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.6172 - loss: 0.6516 - val_accuracy: 0.5973 - val_loss: 0.6651 - learning_rate: 4.0000e-05
# Epoch 33/500
# 597/597 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6173 - loss: 0.6510 - val_accuracy: 0.5974 - val_loss: 0.6651 - learning_rate: 4.0000e-05
# Epoch 34/500
# 597/597 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6177 - loss: 0.6524 - val_accuracy: 0.5971 - val_loss: 0.6649 - learning_rate: 4.0000e-05
# Epoch 35/500
# 597/597 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.6176 - loss: 0.6515 - val_accuracy: 0.5971 - val_loss: 0.6652 - learning_rate: 4.0000e-05
# Epoch 36/500
# 582/597 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6142 - loss: 0.6557
# Epoch 36: ReduceLROnPlateau reducing learning rate to 8.000000525498762e-06.
# 597/597 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.6168 - loss: 0.6519 - val_accuracy: 0.5977 - val_loss: 0.6651 - learning_rate: 4.0000e-05

# %%
# Évaluation Classification
loss_c, acc_c = model_class.evaluate(X_test_c, y_test_c)
print(f"\nAccuracy sur le Test Set : {acc_c:.4f}")

# Plot
plt.plot(history_class.history['loss'], label='train_loss')
plt.plot(history_class.history['val_loss'], label='val_loss')
plt.title('Perte Classification')
plt.legend()
plt.show()
# Out:
#  79/264 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6012 - loss: 0.6616
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6118 - loss: 0.6546
#
# Accuracy sur le Test Set : 0.6118

# %% [markdown]
# ## 3. PARTIE 2 : RÉGRESSION
# ---
#
# Objectif : Prédire les 4 variables continues simultanément.

# %%
# Split des données
X_train_r, X_test_r, y_train_r, y_test_r = train_test_split(
    X_reg.values, y_reg.values, test_size=0.15, random_state=42
)

# %%
model_reg = Sequential([
    Input(shape=(X_train_r.shape[1],)),
    
    Dense(256),
    BatchNormalization(),
    Activation('swish'),
    Dropout(0.3),
    
    Dense(128),
    BatchNormalization(),
    Activation('swish'),
    Dropout(0.2),
    
    Dense(64),
    BatchNormalization(),
    Activation('swish'),
    Dropout(0.1),
    
    Dense(32, activation='swish'),
    Dense(4) # Sortie pour les 4 cibles
])

optimizer = tf.keras.optimizers.Adam(learning_rate=0.001)
model_reg.compile(optimizer=optimizer, loss='mse', metrics=['mae'])
model_reg.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_4 (Dense)                 │ (None, 256)            │         9,728 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 256)            │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_3 (Activation)       │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_4           │ (None, 128)            │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_4 (Activation)       │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_5           │ (None, 64)             │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_5 (Activation)       │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_5 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_8 (Dense)                 │ (None, 4)              │           132 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 54,884 (214.39 KB)
#  Trainable params: 53,988 (210.89 KB)
#  Non-trainable params: 896 (3.50 KB)

# %%
# Entraînement
history_reg = model_reg.fit(
    X_train_r, y_train_r, 
    epochs=500, 
    batch_size=32, 
    validation_split=0.1,
    callbacks = [
    tf.keras.callbacks.EarlyStopping(
        monitor='val_loss',
        patience=20,
        restore_best_weights=True
    ),
    tf.keras.callbacks.ReduceLROnPlateau(
        monitor='val_loss',
        factor=0.5,
        patience=30,
        min_lr=1e-6,
        verbose=1
    )
    ],
    verbose=1
)
# Out:
# Epoch 1/500
# 1343/1343 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 340.4551 - mae: 10.1619 - val_loss: 102.3217 - val_mae: 6.5404 - learning_rate: 0.0010
# Epoch 2/500
# 1343/1343 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 113.7430 - mae: 6.8695 - val_loss: 99.4809 - val_mae: 6.4447 - learning_rate: 0.0010
# Epoch 3/500
# 1343/1343 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 109.3074 - mae: 6.7410 - val_loss: 100.1659 - val_mae: 6.4737 - learning_rate: 0.0010
# Epoch 4/500
# 1343/1343 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 103.8521 - mae: 6.5924 - val_loss: 89.3269 - val_mae: 6.1668 - learning_rate: 0.0010
# Epoch 5/500
# 1343/1343 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 75.6567 - mae: 5.6603 - val_loss: 51.5706 - val_mae: 4.6268 - learning_rate: 0.0010
# Epoch 6/500
# 1343/1343 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 58.5647 - mae: 4.9569 - val_loss: 46.1148 - val_mae: 4.1839 - learning_rate: 0.0010
# Epoch 7/500
# 1343/1343 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 55.7439 - mae: 4.8106 - val_loss: 45.3261 - val_mae: 4.0739 - learning_rate: 0.0010
# Epoch 8/500
# 1343/1343 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 53.7674 - mae: 4.7093 - val_loss: 48.3388 - val_mae: 4.4007 - learning_rate: 0.0010
# Epoch 9/500
# 1343/1343 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 52.0767 - mae: 4.6229 - val_loss: 45.0156 - val_mae: 4.0392 - learning_rate: 0.0010
# Epoch 10/500
# 1343/1343 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 51.2742 - mae: 4.5853 - val_loss: 44.7651 - val_mae: 4.0003 - learning_rate: 0.0010
# Epoch 11/500
# 1343/1343 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 50.4182 - mae: 4.5368 - val_loss: 44.3336 - val_mae: 3.9428 - learning_rate: 0.0010
# Epoch 12/500
# 1343/1343 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 49.4825 - mae: 4.4875 - val_loss: 44.1735 - val_mae: 3.9688 - learning_rate: 0.0010
# Epoch 13/500
# 1343/1343 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 48.9642 - mae: 4.4405 - val_loss: 44.1643 - val_mae: 3.8864 - learning_rate: 0.0010
# Epoch 14/500
# 1343/1343 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 48.3125 - mae: 4.4100 - val_loss: 44.3091 - val_mae: 4.0052 - learning_rate: 0.0010
# Epoch 15/500
# 1343/1343 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - loss: 47.8786 - mae: 4.3889 - val_loss: 45.4891 - val_mae: 4.1557 - learning_rate: 0.0010
# Epoch 16/500
# 1343/1343 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - loss: 47.6891 - mae: 4.3766 - val_loss: 43.5512 - val_mae: 3.8764 - learning_rate: 0.0010
# Epoch 17/500
# 1343/1343 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 47.1182 - mae: 4.3366 - val_loss: 43.7113 - val_mae: 3.9225 - learning_rate: 0.0010
# Epoch 18/500
# 1343/1343 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 46.8721 - mae: 4.3223 - val_loss: 43.4192 - val_mae: 3.8674 - learning_rate: 0.0010
# Epoch 19/500
# 1343/1343 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 46.6828 - mae: 4.3076 - val_loss: 43.4349 - val_mae: 3.8661 - learning_rate: 0.0010
# Epoch 20/500
# 1343/1343 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 46.5638 - mae: 4.2993 - val_loss: 42.9174 - val_mae: 3.7847 - learning_rate: 0.0010
# Epoch 21/500
# 1343/1343 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 46.3083 - mae: 4.2792 - val_loss: 43.2679 - val_mae: 3.8239 - learning_rate: 0.0010
# Epoch 22/500
# 1343/1343 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 46.0235 - mae: 4.2603 - val_loss: 43.1413 - val_mae: 3.8174 - learning_rate: 0.0010
# Epoch 23/500
# 1343/1343 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 46.0406 - mae: 4.2657 - val_loss: 42.9145 - val_mae: 3.7799 - learning_rate: 0.0010
# Epoch 24/500
# 1343/1343 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 45.8415 - mae: 4.2507 - val_loss: 43.3527 - val_mae: 3.8356 - learning_rate: 0.0010
# Epoch 25/500
# 1343/1343 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 45.6395 - mae: 4.2317 - val_loss: 42.9864 - val_mae: 3.7681 - learning_rate: 0.0010
# Epoch 26/500
# 1343/1343 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 45.5183 - mae: 4.2265 - val_loss: 43.0795 - val_mae: 3.8036 - learning_rate: 0.0010
# Epoch 27/500
# 1343/1343 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 45.4660 - mae: 4.2203 - val_loss: 43.1297 - val_mae: 3.8106 - learning_rate: 0.0010
# Epoch 28/500
# 1343/1343 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 45.3402 - mae: 4.2117 - val_loss: 42.8977 - val_mae: 3.7810 - learning_rate: 0.0010
# Epoch 29/500
# 1343/1343 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 45.3680 - mae: 4.2140 - val_loss: 43.0944 - val_mae: 3.7695 - learning_rate: 0.0010
# Epoch 30/500
# 1343/1343 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 45.3291 - mae: 4.2139 - val_loss: 42.7215 - val_mae: 3.7396 - learning_rate: 0.0010
# Epoch 31/500
# 1343/1343 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 45.0150 - mae: 4.1932 - val_loss: 43.3584 - val_mae: 3.8201 - learning_rate: 0.0010
# Epoch 32/500
# 1343/1343 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 45.1585 - mae: 4.1982 - val_loss: 43.3109 - val_mae: 3.8216 - learning_rate: 0.0010
# Epoch 33/500
# 1343/1343 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 45.1234 - mae: 4.1990 - val_loss: 43.0678 - val_mae: 3.7529 - learning_rate: 0.0010
# Epoch 34/500
# 1343/1343 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 45.0840 - mae: 4.2011 - val_loss: 43.5371 - val_mae: 3.8297 - learning_rate: 0.0010
# Epoch 35/500
# 1343/1343 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 45.0102 - mae: 4.1866 - val_loss: 43.5712 - val_mae: 3.9022 - learning_rate: 0.0010
# Epoch 36/500
# 1343/1343 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 45.0171 - mae: 4.1942 - val_loss: 42.8555 - val_mae: 3.7793 - learning_rate: 0.0010
# Epoch 37/500
# 1343/1343 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 44.8306 - mae: 4.1780 - val_loss: 42.7657 - val_mae: 3.7185 - learning_rate: 0.0010
# Epoch 38/500
# 1343/1343 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 44.7569 - mae: 4.1726 - val_loss: 43.2759 - val_mae: 3.7689 - learning_rate: 0.0010
# Epoch 39/500
# 1343/1343 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 44.8669 - mae: 4.1807 - val_loss: 42.8666 - val_mae: 3.7085 - learning_rate: 0.0010
# Epoch 40/500
# 1343/1343 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 44.6587 - mae: 4.1631 - val_loss: 43.1638 - val_mae: 3.7700 - learning_rate: 0.0010
# Epoch 41/500
# 1343/1343 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 44.5904 - mae: 4.1643 - val_loss: 42.8453 - val_mae: 3.7664 - learning_rate: 0.0010
# Epoch 42/500
# 1343/1343 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 44.6889 - mae: 4.1762 - val_loss: 43.1403 - val_mae: 3.7523 - learning_rate: 0.0010
# Epoch 43/500
# 1343/1343 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 44.6243 - mae: 4.1643 - val_loss: 43.4728 - val_mae: 3.7615 - learning_rate: 0.0010
# Epoch 44/500
# 1343/1343 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 44.4570 - mae: 4.1515 - val_loss: 43.0563 - val_mae: 3.8244 - learning_rate: 0.0010
# Epoch 45/500
# 1343/1343 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 44.4280 - mae: 4.1552 - val_loss: 43.1015 - val_mae: 3.8037 - learning_rate: 0.0010
# Epoch 46/500
# 1343/1343 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 44.5849 - mae: 4.1632 - val_loss: 42.7829 - val_mae: 3.6991 - learning_rate: 0.0010
# Epoch 47/500
# 1343/1343 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 44.4381 - mae: 4.1575 - val_loss: 43.1989 - val_mae: 3.7935 - learning_rate: 0.0010
# Epoch 48/500
# 1343/1343 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 44.3015 - mae: 4.1427 - val_loss: 42.7708 - val_mae: 3.7461 - learning_rate: 0.0010
# Epoch 49/500
# 1343/1343 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 44.3598 - mae: 4.1517 - val_loss: 42.8152 - val_mae: 3.6984 - learning_rate: 0.0010
# Epoch 50/500
# 1343/1343 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 44.3189 - mae: 4.1476 - val_loss: 42.7246 - val_mae: 3.6794 - learning_rate: 0.0010

# %%
# Évaluation Régression
y_pred_r = model_reg.predict(X_test_r)

# Pas d'inverse_transform car les y ne sont pas normalisés
y_pred_orig = y_pred_r
y_test_orig = y_test_r

target_names = ['Quiz_Score_Avg', 'Project_Grade', 'Satisfaction_Rating', 'Time_Spent_Hours']
for i, name in enumerate(target_names):
    rmse = np.sqrt(mean_squared_error(y_test_orig[:, i], y_pred_orig[:, i]))
    r2 = r2_score(y_test_orig[:, i], y_pred_orig[:, i])
    print(f"{name} -> RMSE: {rmse:.4f}, R2: {r2:.4f}")

# Plot Loss Régression
plt.plot(history_reg.history['loss'], label='train_mse')
plt.plot(history_reg.history['val_loss'], label='val_mse')
plt.title('Loss Régression')
plt.legend()
plt.show()
# Out:
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Quiz_Score_Avg -> RMSE: 12.3447, R2: 0.0490
# Project_Grade -> RMSE: 1.8545, R2: 0.9853
# Satisfaction_Rating -> RMSE: 0.7090, R2: -0.0053
# Time_Spent_Hours -> RMSE: 3.6658, R2: 0.0634
